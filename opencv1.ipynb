# %%
import string

# %%
1+1
# Out:
# 2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
img=cv2.imread('imgs/chat1.jpg')
cv2.imshow('cat',img)
cv2.waitKey()
# Out:
# -1

# %%
#web/live camera
#key 0 is camera...
import cv2
cap= cv2.VideoCapture(1)
while(True): #tant la camera est allumée
    ret,frame=cap.read() #sortie de la fonction = ret and frame , ret = if there is frame i
    #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) 
    #frame_rescale=changeRes(frame.shape[1],frame.shape[0])

    

    cv2.imshow('frame',frame)
    if cv2.waitKey(1) &  0xff==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [2], line 12
#       6 ret,frame=cap.read() #sortie de la fonction = ret and frame , ret = if there is frame i
#       7 #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#       8 #frame_rescale=changeRes(frame.shape[1],frame.shape[0])
# ---> 12 cv2.imshow('frame',frame)
#      13 if cv2.waitKey(1) &  0xff==ord('q'):
#      14     break
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
#detection des contours
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
plt.imshow(img_blur)

# %%
sobelx = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5)
plt.imshow(sobelx)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
edges = cv2.Canny(image=img, threshold1=100, threshold2=200)
plt.imshow(edges)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#reading an image 
img2=cv2.imread('imgs/baby1.jpg')
cv2.imshow('baby',img2)

#rescaled img:
img2_resized=rescaleFrame(img2)
cv2.imshow('baby_rescale',img2_resized)

cv2.waitKey()
# Out:
# -1

# %%
#reading videos 
capture=cv2.VideoCapture('videos/text.mp4')

while True:
    isTrue,frame=capture.read() #this function returns evry frame and tells us eather if this frame was readed or not
    cv2.imshow('valorant_fade',frame) #to read 1 frame

    #rescaled video:
    #frame_resized=rescaleFrame(frame)
    #cv2.imshow('valorant_fade_rescale',frame_resized)

    if cv2.waitKey(20) &  0xFF==ord('d'): #press d to break out of this loop 
        break
capture.release()
cv2.destroyAllWindows()

# %%
#rescale

def rescaleFrame(frame,scale=0.4):
    width=int(frame.shape[1]*scale) #frame.shape[1] is the width of the original vid or img
    height=int(frame.shape[0]*scale) #frame.shape[0] is the height of the original vid or img

    dimensions=(width,height)    

    return cv2.resize(frame,dimensions,interpolation=cv2.INTER_AREA)

#rescaling videos (only work for videos from web/live camera)

def changeRes(width,height):
    capture.set(3,width)
    capture.set(4,height)

# %%
#Draw

blank=np.zeros((500,500,3),dtype='uint8') #shape 3 of color channels xxx,xxx,xxx
cv2.imshow('balnk',blank)


#img=cv2.imread('imgs/chat1.jpg')
#cv2.imshow('cat',img)

#paint the img in certain color
blank[:]=255,228,196 #refernce all the pixels [:]
cv2.imshow('blue',blank)


blank[100:150,100:150]=255,228,196 #refernce to a portion of the pixels [:]
cv2.imshow('blue',blank)

#Draw a rectangle 

cv2.rectangle(blank,(0,0),(250,250),(150,50,200),thickness=2)
cv2.imshow('rectangle',blank)

#cv2.rectangle(blank,(0,0),(250,500),(150,50,200),cv2.FILLED) #thickness=-1 "LIKE cv2.FILLED"
#cv2.imshow('rectangle',blank)

cv2.rectangle(blank,(0,0),(blank.shape[1]//3,blank.shape[0]//3),(150,50,200),thickness=-1)
cv2.imshow('rectangle',blank)

#Draw a circle

cv2.circle(blank,(blank.shape[1]//2,blank.shape[0]//2),40,(150,50,200),thickness=-1)
cv2.imshow('circle',blank)


#Draw line

cv2.line(blank,(0,350),(500,350),(150,50,200),thickness=2)
cv2.imshow('line',blank)

#Write tex

cv2.putText(blank,'Hello!',(205,349),cv2.FONT_HERSHEY_TRIPLEX,1.0,(150,50,200),1)
cv2.imshow('text',blank)


cv2.waitKey()
# Out:
# -1

# %% [markdown]
# 5 ESSENTIAL FUNCTIONS IN OPENCV

# %%
#Converting and img to grayscale 

img=cv2.imread('imgs/baby1.jpg')
img=rescaleFrame(img)
cv2.imshow('baby',img)



gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow('baby_gray',gray)


cv2.waitKey()
# Out:
# -1

# %%
#Blur : reduce the noise in an img

img=cv2.imread('imgs/garden1.jpg')
#img=rescaleFrame(img)
cv2.imshow('garden',img)




blur=cv2.GaussianBlur(img,(7,7),cv2.BORDER_DEFAULT)
cv2.imshow('blur',blur)


cv2.waitKey()
# Out:
# -1

# %%
#Edge cascades (canny)

img=cv2.imread('imgs/sage.jpg')
img=rescaleFrame(img)
cv2.imshow('sage',img)

canny= cv2.Canny(img,125,175)
cv2.imshow('canny',canny)

#to reduce the amount of edges u can use the blur:
blur=cv2.GaussianBlur(img,(3,3),cv2.BORDER_DEFAULT)


canny= cv2.Canny(blur,125,175)
cv2.imshow('canny',canny)

cv2.waitKey()
# Out:
# -1

# %%
#Dilating the img

img=cv2.imread('imgs/sage.jpg')
img=rescaleFrame(img)
cv2.imshow('sage',img)

canny= cv2.Canny(img,125,175)
cv2.imshow('canny',canny)

dilated=cv2.dilate(canny,(3,3),iterations=3)
cv2.imshow('dilated',dilated)





cv2.waitKey()
# Out:
# -1

# %%
#Eroding an img

eroded=cv2.erode(dilated,(3,3),iterations=3)
cv2.imshow('eroded',eroded)

cv2.waitKey()
# Out:
# -1

# %%
#Resize


img=cv2.imread('imgs/sage.jpg')
resized = cv2.resize(img,(1000,500))
cv2.imshow('resized',resized)


cv2.waitKey()
# Out:
# -1

# %%
#Cropping

img=cv2.imread('imgs/sage.jpg')
croped=img[200:700,200:800]
cv2.imshow('croped',croped)

cv2.waitKey()
# Out:
# -1

# %% [markdown]
# Contour Detection

# %%
#Contour detection

img=cv2.imread('imgs/cats.jpg')
#img = cv2.resize(img,(500,600))
cv2.imshow('cats',img)



gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow('cats_gray',gray)

#ret,thresh =cv2.threshold(gray,125,255,cv2.THRESH_BINARY)
#cv2.imshow('thresh',thresh)


blur=cv2.GaussianBlur(gray,(3,3),cv2.BORDER_DEFAULT)
cv2.imshow('blur',blur)


canny= cv2.Canny(blur,125,175)
cv2.imshow('canny',canny)

contours,hierarchies=cv2.findContours(canny,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)  #CONTOURS=A PYTHON LIST OF ALL THE COORDINATES IF THE CONTOURS THAT WHERE FOUND IN THE IMG ||| HIERARCHIES= THE HIERACHICAL REPRESENTATION OF CONTOURS
print(f"{len(contours)} countour(s) found!")


blank=np.zeros(img.shape,dtype='uint8')
cv2.imshow('blank',blank)



cv2.drawContours(blank,contours,-1,(0,0,200),1) #1 means that we want all the contours and 2 is the thickness
cv2.imshow('contours_draw',blank)











cv2.waitKey()
# Out:
# 1402 countour(s) found!
# -1

# %% [markdown]
# Blurring

# %%
#Averging

img=cv2.imread('imgs/garden1.jpg')
img = cv2.resize(img,(600,500))
cv2.imshow('cat',img)
 # define a kernel window three by three (3x3) and computed the center value using the average of all surrouding pixel intensities
average=cv2.blur(img,(3,3))
cv2.imshow('average',average)

blur=cv2.GaussianBlur(img,(3,3),cv2.BORDER_DEFAULT) #MORE NATUREL THAN THE AVERAGE blur
cv2.imshow('blur',blur)

median=cv2.medianBlur(img,3)
cv2.imshow('median',median)

cv2.waitKey()
# Out:
# -1

# %%
#GaussianBlur

img=cv2.imread('imgs/chat1.jpg')
img = cv2.resize(img,(600,500))
blur=cv2.GaussianBlur(img,(3,3),cv2.BORDER_DEFAULT) #MORE NATUREL THAN THE AVERAGE blur
cv2.imshow('blur',blur)



cv2.waitKey()
# Out:
# -1

# %%
#Median blur

img=cv2.imread('imgs/garden1.jpg')
img= cv2.resize(img,(600,500)) #good for removing the noises in the img

median=cv2.medianBlur(img,3)
cv2.imshow('median',median)

cv2.waitKey()
# Out:
# -1

# %%
#Bilateral bliring ==> applies bluring but keeps the edges in the image!

img=cv2.imread('imgs/cake2.jpg')
img= cv2.resize(img,(600,500))
cv2.imshow('cake',img)


bilateral=cv2.bilateralFilter(img,10,35,25)
cv2.imshow('bilateral',bilateral)

cv2.waitKey()
# Out:
# -1

# %% [markdown]
#  BITWISE operations

# %%
#BITWISE 

blank=np.zeros((400,400),dtype='uint8')
rectangle=cv2.rectangle(blank.copy(),(30,30),(370,370),255,-1)
circle=cv2.circle(blank.copy(),(200,200),200,255,-1)

cv2.imshow('rectangle',rectangle)
cv2.imshow('circle',circle)


#Bitwise AND (intersection)

bitwise_and=cv2.bitwise_and(rectangle,circle)
cv2.imshow('bitwise_and',bitwise_and)


#Bitwise OR  (intersaction+nonintersaction)

bitwise_or=cv2.bitwise_or(rectangle,circle)
cv2.imshow('bitwise_or',bitwise_or)


#Bitwise XOR (non intersaction)

bitwise_xor=cv2.bitwise_xor(rectangle,circle)
cv2.imshow('bitwise_xor',bitwise_xor)


#Bitwise NOT

bitwise_not=cv2.bitwise_not(rectangle)
cv2.imshow('bitwise_not',bitwise_not)


cv2.waitKey()
# Out:
# -1

# %%
#Face Detection Haar_Cascades (image)



img=cv2.imread('imgs/people1.jpg')
img= cv2.resize(img,(750,500))

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


haar_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces_rect=haar_cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=4)
    
for(x,y,z,h) in faces_rect :
    cv2.rectangle(img,(x,y),(x+z,y+h),(0,255,0),2)


cv2.imshow('Detected faces ',img)

print(f"Number of faces found = {len(faces_rect)}")




cv2.waitKey()
# Out:
# Number of faces found = 9
# -1

# %%
#Face Detection Haar_Cascades (video)



#haar_cascade=cv2.CascadeClassifier('haar_face.xml')




cap= cv2.VideoCapture(0)
while(True): #tant la camera est allumée
    ret,frame=cap.read() #sortie de la fonction = ret and frame , ret = if there is frame i
    #gray=cv2.cvtColor(frame,cv2.COLOR_BAYER_BG2GRAY) 
    #frame_rescale=changeRes(frame.shape[1],frame.shape[0])


    haar_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    faces_rect=haar_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=10)
    
    for(x,y,z,h) in faces_rect :
        cv2.rectangle(frame,(x,y),(x+z,y+h),(0,255,0),2)


    cv2.imshow('frame',frame)
    if cv2.waitKey(1) &  0xff==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()



print(f"Number of faces found = {len(faces_rect)}")






#cv2.imshow('Detected faces ',img)


cv2.waitKey()
# Out:
# Number of faces found = 1
# -1

# %%
#Tracking

from tracker import*

tracker = EuclideanDistTracker() #this tracker takes all the bounding boxes of the objects into oone array

cap =cv2.VideoCapture("videos/highway.mp4")

object_detector=cv2.createBackgroundSubtractorMOG2(history=100,varThreshold=50) #extrate the moving objects from the stable camera


while(True): #tant la camera est allumée
    ret,frame=cap.read() #sortie de la fonction = ret and frame , ret = if there is frame i
    #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) Q

    #height,width,_ = frame.shape
    #print(height,width)

    # Extract region of interest
  
    region=frame


    #1 object detection
    mask=object_detector.apply(region)
    cv2.imshow('mask',mask)

    threshold,thresh=cv2.threshold(mask,254,255,cv2.THRESH_BINARY)
    
    
    
    contours,hierarchies=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)


    detections=[]

    for cnt in contours:
        


        #Calculate area and remove all the small elmnts

        area=cv2.contourArea(cnt)
        if area > 100:
            #cv2.drawContours(region,[cnt],-1,(0,255,0),2)
             
            x,y,w,h =cv2.boundingRect(cnt)
            #cv2.rectangle(region,(x,y),(x+w,y+h),(0,255,0),2)
            print(x,y,w,h)

            detections.append([x,y,w,h])
            #print(detections)



    #2 object tracking

    boxes_ids=tracker.update(detections) # boxesid is detection list plux the tracker
    #print( boxes_id)
    for box_id in boxes_ids:
        x,y,w,h,id=box_id
        cv2.putText(region,str(id),(x+w//2,y-15),cv2.FONT_HERSHEY_PLAIN,2,(0,250,0),2)
        cv2.rectangle(region,(x,y),(x+w,y+h),(0,255,0),2)



    cv2.imshow('region',region)
    cv2.imshow('frame',frame)

    if cv2.waitKey(1) &  0xff==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 656 410 15 27
# 183 260 19 29
# 222 245 16 38
# 654 407 17 36
# 5 277 20 17
# 179 263 26 29
# 222 247 13 36
# {0: (662, 425), 1: (192, 274), 2: (230, 264)}
# {0: (662, 425), 1: (192, 277), 2: (230, 264), 3: (15, 285)}
# {0: (662, 425), 1: (192, 277), 2: (228, 265), 3: (15, 285)}
# 5 272 30 17
# {0: (662, 425), 3: (20, 280), 1: (192, 277), 2: (228, 265)}
# 4 268 40 16
# {3: (24, 276)}
# 164 272 19 27
# 4 264 49 20
# {3: (28, 274), 4: (173, 285)}
# 656 452 11 20
# 162 272 20 31
# 8 260 54 20
# {4: (172, 287), 3: (28, 274), 5: (661, 462)}
# {4: (172, 287), 3: (35, 270), 5: (661, 462)}
# 654 453 19 29
# 156 274 18 32
# 17 257 53 19
# {5: (663, 467), 4: (172, 287), 3: (35, 270)}
# {5: (663, 467), 4: (165, 290), 3: (35, 270)}
# {5: (663, 467), 4: (165, 290), 3: (43, 266)}
# 653 463 18 28
# 152 275 18 31
# 27 253 51 20
# {5: (662, 477), 4: (165, 290), 3: (43, 266)}
# {5: (662, 477), 4: (161, 290), 3: (43, 266)}
# {5: (662, 477), 4: (161, 290), 3: (52, 263)}
# 656 480 15 19
# 148 279 18 30
# ...

# %%
cv2.waitKey()
#Draw a rectangle 

cv2.rectangle(blank,(0,0),(250,250),(150,50,200),thickness=2)
cv2.imshow('rectangle',blank)

#cv2.rectangle(blank,(0,0),(250,500),(150,50,200),cv2.FILLED) #thickness=-1 "LIKE cv2.FILLED"
#cv2.imshow('rectangle',blank)

cv2.rectangle(blank,(0,0),(blank.shape[1]//3,blank.shape[0]//3),(150,50,200),thickness=-1)
cv2.imshow('rectangle',blank)

#Draw a circle

cv2.circle(blank,(blank.shape[1]//2,blank.shape[0]//2),40,(150,50,200),thickness=-1)
cv2.imshow('circle',blank)


#Draw line

cv2.line(blank,(0,350),(500,350),(150,50,200),thickness=2)
cv2.imshow('line',blank)

#Write tex

cv2.putText(blank,'Hello!',(205,349),cv2.FONT_HERSHEY_TRIPLEX,1.0,(150,50,200),1)
cv2.imshow('text',blank)


cv2.waitKey()

# %%
import cv2
import numpy as np
blank=np.zeros((600,600),dtype='uint8') 
cv2.line(blank,(10,10),(30,15),(150,50,200),thickness=2)


cv2.imshow("ii",blank)
cv2.waitKey()
# Out:
# 113
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
